# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LogisticRegression
#from sklearn.

data=pd.read_csv('../input/heartdisease-2/heart_disease.csv')
labels=data.values[:,-1]
labels[labels>1]=1
labels=labels.astype(int)

data=data.values[:,:-1]

lr=LogisticRegression()

# %%
data = (data - np.mean(data, axis=0))/np.std(data, axis=0)
data = np.column_stack((data, np.ones(data.shape[0])))
print(data)
lr.fit(data,labels)
# Out:
# [[ 0.94872647  0.68620244 -2.25177456 ... -0.71113139  0.65913253
#    1.        ]
#  [ 1.39200191  0.68620244  0.87798549 ...  2.5048807  -0.86542592
#    1.        ]
#  [ 1.39200191  0.68620244  0.87798549 ...  1.43287667  1.16731868
#    1.        ]
#  ...
#  [ 0.28381332  0.68620244  0.87798549 ...  0.36087264  1.16731868
#    1.        ]
#  [ 0.28381332 -1.4572959  -1.20852121 ...  0.36087264 -0.86542592
#    1.        ]
#  [-1.82174501  0.68620244 -0.16526786 ... -0.71113139 -0.86542592
#    1.        ]]
# LogisticRegression()

# %%
# Cross-validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
folds = [3,5,7,10,20,50]
for k in folds:
    cv = KFold(n_splits=k)
    scores = cross_validate(lr, data, labels, scoring='accuracy', cv=cv, return_train_score=True)
    #print(scores.keys())
    print('%i fold Accuracy train score: %.3f (%.3f)' % (k, np.mean(scores['train_score']), np.std(scores['train_score'])))
    print('%i fold Accuracy test score: %.3f (%.3f)' % (k, np.mean(scores['test_score']), np.std(scores['test_score'])))
# Out:
# 3 fold Accuracy train score: 0.853 (0.010)
# 3 fold Accuracy test score: 0.828 (0.025)
# 5 fold Accuracy train score: 0.853 (0.016)
# 5 fold Accuracy test score: 0.822 (0.071)
# 7 fold Accuracy train score: 0.858 (0.010)
# 7 fold Accuracy test score: 0.835 (0.053)
# 10 fold Accuracy train score: 0.853 (0.008)
# 10 fold Accuracy test score: 0.822 (0.098)
# 20 fold Accuracy train score: 0.850 (0.007)
# 20 fold Accuracy test score: 0.835 (0.109)
# 50 fold Accuracy train score: 0.850 (0.005)
# 50 fold Accuracy test score: 0.824 (0.165)

# %% [markdown]
# I think the 7 fold performs best, because the standard deviation is the smallest for the test set and the mean accuracy is the best for both training and test set.
